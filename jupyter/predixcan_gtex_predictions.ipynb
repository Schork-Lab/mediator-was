# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import gzip
import sys
import os
sys.path.append('../src/')

# %%
import data.gtex as gtex
import data.gustavo as gustavo
import yaml

# %%
config = yaml.load(open('../config.yaml'))

# %%
config
# Out:
# {'data': {'gtex': {'dir': '/projects/gtex'},
#   'gustavo': {'dir': '/home/kbhutani/mediator-was/data/predixcan/',
#    'files': {'database': 'DGN-WB_0.5.txt'}},
#   'references': {'dbsnp': '/projects/references/snp142Common.txt.gz'}}}

# %% [markdown]
# #### Process and load Gustavo Data

# %%
# Add positions to database
new_db = os.path.join(gustavo.main_dir, "EN.withpos.tsv")
#gustavo.add_positions_to_database(fn=new_db)

# %%
# Load database
en_df = gustavo.load_database(new_db)

# %%
en_df.head()
# Out:
#     gene        rsid refAllele alt      beta  alpha    id    chr      start  \
# 0  A2LD1  rs11069419         T   C -0.034054      1  1359  chr13  101561096
# 1  A2LD1  rs11842969         C   T -0.381005      1  1357  chr13  101214374
# 2  A2LD1   rs1283142         C   A -0.013816      1  1358  chr13  101392263
# 3  A2LD1   rs1283211         C   T  0.022643      1  1358  chr13  101369270
# 4  TMTC4   rs1283211         C   T  0.006821      1  1358  chr13  101369270
#
#          end chromosome   position
# 0  101561097      chr13  101561097
# 1  101214375      chr13  101214375
# 2  101392264      chr13  101392264
# 3  101369271      chr13  101369271
# 4  101369271      chr13  101369271

# %% [markdown]
# ### Predicted Values

# %% [markdown]
# ##### Unit Test for Predicted Values

# %%
example_vcf = "../examples/example.vcf"
example_db = gustavo.load_database('../examples/example_database.tsv')

# %%
predictions_df, not_found, incorrect, switched = gustavo.predict_expression(example_db, example_vcf)
# Out:
# Total 289
# Not Found 0
# Incorrect 0
# Switched 0

# %%
predictions_df
# Out:
#        GTEX-P4PP-0004-SM-2H2WW  GTEX-PWO3-0004-SM-2IJGP  \
# ERAP2                -0.559434                -0.404516
# ERAP1                -2.297441                -1.845815
# NUDT2                 1.060489                 2.810289
# PEX6                  2.955233                 1.950844
#
#        GTEX-SNOS-0004-SM-325AE  GTEX-PW2O-0004-SM-2IJGJ  \
# ERAP2                -0.485815                -0.428508
# ERAP1                -1.799580                -3.184664
# NUDT2                 2.302246                 0.842125
# PEX6                  0.233295                -0.000748
#
#        GTEX-RU72-0004-SM-2RXF6  GTEX-VJYA-0003-SM-3G3S9  \
# ERAP2                -0.519012                 1.286793
# ERAP1                -0.933059                -0.927582
# NUDT2                 3.637754                 3.388741
# PEX6                  1.890358                 2.951798
#
#        GTEX-U3ZH-0003-SM-3G3RZ  GTEX-PLZ4-0003-SM-2IJGB  \
# ...

# %%
example_predictions = pd.read_table('../examples/example_prediction.tsv',
                                   sep="\t")
example_predictions.T
# Out:
#                             0                        1    \
# Sample  GTEX-P4PP-0004-SM-2H2WW  GTEX-PWO3-0004-SM-2IJGP
# ERAP2                -0.5585247               -0.4045162
# NUDT2                   1.05067                 2.810289
# PEX6                   2.955233                 1.950844
# ERAP1                 -2.297441                -1.845815
#
#                             2                        3    \
# Sample  GTEX-SNOS-0004-SM-325AE  GTEX-PW2O-0004-SM-2IJGJ
# ERAP2                -0.4446278               -0.4305714
# NUDT2                  2.302246                0.8369547
# PEX6                  0.2332947              -0.00074846
# ERAP1                 -1.792753                -3.184664
#
#                             4                        5    \
# Sample  GTEX-RU72-0004-SM-2RXF6  GTEX-VJYA-0003-SM-3G3S9
# ERAP2                 -0.519012                 1.306758
# NUDT2                  3.659646                 3.418891
# ...

# %% [markdown]
# #### It's very close. Got to dig into the unit test later.'

# %%
genotype_file = gtex.genotype_fn
predictions_df, not_found, incorrect, switched = gustavo.predict_expression(en_df, genotype_file)
# Out:
# Total 224082
# Not Found 8
# Incorrect 0
# Switched 0

# %%
pd.concat([pd.DataFrame(x).T for x in not_found])
# Out:
#           gene        rsid refAllele alt         beta alpha    id    chr  \
# 21285   HHIPL2  rs34651530         A   G  -0.04849929     1  2286   chr1
# 84491      ZP3  rs17149187         A   G   0.03322222     1  1164   chr7
# 127715   MED17  rs11020719         G   A   -0.0413322     1  1302  chr11
# 138075    KRR1   rs1026784         G   A  -0.04398848     1  1164  chr12
# 151878    FCF1  rs17183663         C   A  0.002284925     1  1164  chr14
# 170927  ZNF469   rs4843756         C   T   0.03219198     1  1256  chr16
# 183491  CD300C   rs3744203         A   G  -0.01866636     1  1141  chr17
# 183492    NT5C   rs3744203         A   G -0.006345411     1  1141  chr17
#
#             start        end chromosome   position
# 21285   222985196  222985197          1  222985197
# 84491    75998572   75998573          7   75998573
# 127715   94008519   94008520         11   94008520
# 138075   75997732   75997733         12   75997733
# 151878   76001456   76001457         14   76001457
# ...

# %% [markdown]
# #### Note that it did not compute on the HLA related genes. Let's remove them from further analysis.

# %%
hla_related_genes = set(en_df[en_df['chromosome'] == 25]['gene'])

# %%
full_predicted_genes = set(predictions_df.index) - hla_related_genes
full_predicted_df = predictions_df.ix[full_predicted_genes]
full_predicted_df.columns = full_predicted_df.columns.map(lambda x: "-".join(x.split('-')[:2]))

# %%
full_predicted_df.head()
# Out:
#         GTEX-P4PP  GTEX-PWO3  GTEX-SNOS  GTEX-PW2O  GTEX-RU72  GTEX-VJYA  \
# UBE2Q1  -0.121079  -0.066371   0.135165   0.043322  -0.167153   0.059409
# RNF14   -0.344138  -0.144490  -0.348426   0.056915  -0.163442  -0.328642
# UBE2Q2   0.185559   0.194231  -0.018047   0.290495   0.092135  -0.163189
# RNF10   -0.032507  -0.068161  -0.056125  -0.047314   0.041432  -0.046286
# RNF13    0.706117   0.000000   0.353058   0.000000   0.000000   0.044834
#
#         GTEX-U3ZH  GTEX-PLZ4  GTEX-P44G  GTEX-WOFL    ...      GTEX-YF7O  \
# UBE2Q1  -0.064592   0.117333   0.053394  -0.029087    ...       0.118536
# RNF14   -0.360858  -0.360858   0.043541  -0.165200    ...      -0.159453
# UBE2Q2   0.311871   0.441576   0.089022   0.124410    ...       0.226836
# RNF10    0.013369  -0.038442  -0.034058  -0.020994    ...      -0.026834
# RNF13    0.000000   0.000000   0.000000   0.353058    ...       0.000000
#
#         GTEX-11TTK  GTEX-Y3IK  GTEX-12WSE  GTEX-1212Z  GTEX-YEC3  GTEX-11ONC  \
# ...

# %%
full_predicted_df.to_csv('../data/predixcan/predictions.minus-hla.tsv',
                        sep="\t")
